# %%
# !pip install langchain_core

# %%
from langchain_ollama import ChatOllama

base_url = 'http://localhost:11434'
model = 'qwen3:0.6b'

llm = ChatOllama(base_url=base_url, model=model)

question = 'tell me about the earth in 3 points'
response = llm.invoke(question)
print(response.content)
# Out:
# 1. **Earth's Composition**: The Earth is composed of about 51% iron, 24% carbon, and 27% oxygen, making it a planet of diverse and dynamic elements.
# 2. **Atmosphere**: It has a unique atmosphere with a mix of nitrogen, oxygen, carbon dioxide, and other gases, essential for sustaining life.
# 3. **Water Availability**: The planet hosts a vast amount of water, including liquid water on its surface and underground, which is critical for ecosystems and human survival.

# %%
from langchain_core.messages import SystemMessage, HumanMessage

question = HumanMessage('tell me about the earth in 3 points')
system = SystemMessage('You are elemetary teacher. You answer in short sentences.')

messages = [system, question]
response = llm.invoke(messages)

print(response.content)
# Out:
# 1. The Earth is a planet with a unique atmosphere composed of nitrogen and oxygen, vital for life.
# 2. It possesses a magnetic field that protects the planet from solar radiation and cosmic rays.
# 3. The Earth is the only known planet with life, making it a critical subject in planetary science.

# %%
from langchain_core.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate, PromptTemplate, ChatPromptTemplate

system = SystemMessagePromptTemplate.from_template('You are {school} teacher. You answer in short sentences.')
question = HumanMessagePromptTemplate.from_template('tell me about the {topics} in {points} points')

system
question
# Out:
# HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['points', 'topics'], input_types={}, partial_variables={}, template='tell me about the {topics} in {points} points'), additional_kwargs={})

# %%
question.format(topics='sun', points=5)
# Out:
# HumanMessage(content='tell me about the sun in 5 points', additional_kwargs={}, response_metadata={})

# %%
system.format(school='elemetary')
# Out:
# SystemMessage(content='You are elemetary teacher. You answer in short sentences.', additional_kwargs={}, response_metadata={})

# %%
messages = [system, question]

template = ChatPromptTemplate(messages)

# %%
question = template.invoke({'school': 'elemetary', 'topics': 'sun', 'points': 5})

response = ChatPromptTemplate(messages)

# %%
question = template.invoke({'school': 'elemetary', 'topics': 'sun', 'points': 5})

response = llm.invoke(question)
print(response.content)
# Out:
# 1. The sun is a massive star that produces energy through nuclear fusion in its core.
# 2. It has a radiative zone, photosphere, and a core, all contributing to its energy output.
# 3. The sun emits light and heat, sustaining life on Earth and influencing weather and climate.
# 4. It plays a vital role in the solar system by providing energy for planets and moons.
# 5. The sun's light and heat are essential for life and climate regulation.
